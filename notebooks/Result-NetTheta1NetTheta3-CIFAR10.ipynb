# %%
import torchvision
import torch.nn as nn
from torchvision.utils import save_image, make_grid
import json
import os
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                        download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# JSON file
with open ('../outputs/IF_test_id_0_epoch_1.json', "r") as f:
     data = json.loads(f.read())

# %%
labels = np.array([i[1] for i in trainset])

# %%
data['influence']

# %% [markdown]
# # Test image

# %%
plt.imshow(testset[0][0])

# %%
labels[data['helpful']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_18310/3443398569.py in <module>
# ----> 1 labels[data['helpful']]
#
# NameError: name 'labels' is not defined

# %%
labels[data['harmful']]

# %%
arr = np.argsort(data['influence'])
rank = [[] for _ in range(10)]
for i in range(5000):
    rank[labels[arr[i]]].append(i)

# %%
sorted(rank[2])

# %%
np.array(data['influence'])[np.argsort(data['influence'])]
# Out:
# array([0.00232309, 0.00354293, 0.00502175, ..., 0.39792687, 0.41112667,
#        0.41172081])

# %%
fig = plt.figure(figsize=(5, 3))
for i in range(1,10):
    fig.add_subplot(3,3,i)
    plt.imshow(trainset[data['helpful'][i]][0])

# %%
fig = plt.figure(figsize=(5, 3))
for i in range(1,10):
    fig.add_subplot(3,3,i)
    plt.imshow(trainset[data['harmful'][i]][0])

# %%
plt.imshow([trainset[data['helpful'][10]][0],trainset[data['helpful'][13]][0]])

# %%
trainset[data['harmful'][15]][0]
